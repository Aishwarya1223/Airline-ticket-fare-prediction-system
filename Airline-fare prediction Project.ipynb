# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
train_data=pd.read_excel("C:\\Users\\aishw\\OneDrive\\Desktop\\Data science - Project files\\Flight_Price_resources\\Data_Train.xlsx")
train_data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
train_data.tail()
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time Arrival_Time Duration Total_Stops  \
# 10678              CCU → BLR    19:55        22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45        23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20        11:20       3h    non-stop
# 10681              BLR → DEL    11:30        14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55        19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
train_data.isnull()
# Out:
#        Airline  Date_of_Journey  Source  Destination  Route  Dep_Time  \
# 0        False            False   False        False  False     False
# 1        False            False   False        False  False     False
# 2        False            False   False        False  False     False
# 3        False            False   False        False  False     False
# 4        False            False   False        False  False     False
# ...        ...              ...     ...          ...    ...       ...
# 10678    False            False   False        False  False     False
# 10679    False            False   False        False  False     False
# 10680    False            False   False        False  False     False
# 10681    False            False   False        False  False     False
# 10682    False            False   False        False  False     False
#
#        Arrival_Time  Duration  Total_Stops  Additional_Info  Price
# ...

# %%
train_data.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
train_data['Total_Stops'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10678    False
# 10679    False
# 10680    False
# 10681    False
# 10682    False
# Name: Total_Stops, Length: 10683, dtype: bool

# %%
train_data[train_data['Total_Stops'].isnull()]
# Out:
#         Airline Date_of_Journey Source Destination Route Dep_Time  \
# 9039  Air India       6/05/2019  Delhi      Cochin   NaN    09:45
#
#       Arrival_Time Duration Total_Stops Additional_Info  Price
# 9039  09:25 07 May  23h 40m         NaN         No info   7480

# %%
train_data.dropna(axis=0,inplace=True)

# %%
train_data.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Price              0
# dtype: int64

# %%
train_data.dtypes
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# dtype: object

# %%
train_data.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10682 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10682 non-null  object
#  1   Date_of_Journey  10682 non-null  object
#  2   Source           10682 non-null  object
#  3   Destination      10682 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10682 non-null  object
#  6   Arrival_Time     10682 non-null  object
#  7   Duration         10682 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10682 non-null  object
#  10  Price            10682 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 7.2 MB

# %%
data=train_data.copy()

# %%
data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
data.dtypes
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# dtype: object

# %%
def change_into_datetime(col):
    data[col]=pd.to_datetime(data[col])

# %%
import warnings
from warnings import filterwarnings
filterwarnings("ignore")

# %%
data.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %%
for feature in ['Dep_Time','Arrival_Time','Date_of_Journey']:
    change_into_datetime(feature)

# %%
data.dtypes
# Out:
# Airline                    object
# Date_of_Journey    datetime64[ns]
# Source                     object
# Destination                object
# Route                      object
# Dep_Time           datetime64[ns]
# Arrival_Time       datetime64[ns]
# Duration                   object
# Total_Stops                object
# Additional_Info            object
# Price                       int64
# dtype: object

# %%
data['Journey_day']=data['Date_of_Journey'].dt.day
data['Journey_day']
# Out:
# 0        24
# 1         5
# 2         6
# 3         5
# 4         3
#          ..
# 10678     4
# 10679    27
# 10680    27
# 10681     3
# 10682     5
# Name: Journey_day, Length: 10682, dtype: int64

# %%
data['Journey_month']=data['Date_of_Journey'].dt.month
data['Journey_month']
# Out:
# 0         3
# 1         1
# 2         9
# 3        12
# 4         1
#          ..
# 10678     9
# 10679     4
# 10680     4
# 10681     1
# 10682     9
# Name: Journey_month, Length: 10682, dtype: int64

# %%
data['Journey_year']=data['Date_of_Journey'].dt.year
data['Journey_year']
# Out:
# 0        2019
# 1        2019
# 2        2019
# 3        2019
# 4        2019
#          ...
# 10678    2019
# 10679    2019
# 10680    2019
# 10681    2019
# 10682    2019
# Name: Journey_year, Length: 10682, dtype: int64

# %%
data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-01-05   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-09-06     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      2019-12-05   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      2019-01-03  Banglore   New Delhi        BLR → NAG → DEL
#
#              Dep_Time        Arrival_Time Duration Total_Stops  \
# 0 2024-05-03 22:20:00 2024-03-22 01:10:00   2h 50m    non-stop
# 1 2024-05-03 05:50:00 2024-05-03 13:15:00   7h 25m     2 stops
# 2 2024-05-03 09:25:00 2024-06-10 04:25:00      19h     2 stops
# 3 2024-05-03 18:05:00 2024-05-03 23:30:00   5h 25m      1 stop
# 4 2024-05-03 16:50:00 2024-05-03 21:35:00   4h 45m      1 stop
#
#   Additional_Info  Price  Journey_day  Journey_month  Journey_year
# ...

# %%
def extract_hour_min(df,col):
    df[col+'_hour']=df[col].dt.hour
    df[col+'_minute']=df[col].dt.minute
    return df.head(3)

# %%
data.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price', 'Journey_day', 'Journey_month',
#        'Journey_year'],
#       dtype='object')

# %%
extract_hour_min(data,'Dep_Time')
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-01-05   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-09-06     Delhi      Cochin  DEL → LKO → BOM → COK
#
#              Dep_Time        Arrival_Time Duration Total_Stops  \
# 0 2024-05-03 22:20:00 2024-03-22 01:10:00   2h 50m    non-stop
# 1 2024-05-03 05:50:00 2024-05-03 13:15:00   7h 25m     2 stops
# 2 2024-05-03 09:25:00 2024-06-10 04:25:00      19h     2 stops
#
#   Additional_Info  Price  Journey_day  Journey_month  Journey_year  \
# 0         No info   3897           24              3          2019
# 1         No info   7662            5              1          2019
# 2         No info  13882            6              9          2019
#
#    Dep_Time_hour  Dep_Time_minute
# 0             22               20
# 1              5               50
# ...

# %%
extract_hour_min(data,'Arrival_Time')
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-01-05   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-09-06     Delhi      Cochin  DEL → LKO → BOM → COK
#
#              Dep_Time        Arrival_Time Duration Total_Stops  \
# 0 2024-05-03 22:20:00 2024-03-22 01:10:00   2h 50m    non-stop
# 1 2024-05-03 05:50:00 2024-05-03 13:15:00   7h 25m     2 stops
# 2 2024-05-03 09:25:00 2024-06-10 04:25:00      19h     2 stops
#
#   Additional_Info  Price  Journey_day  Journey_month  Journey_year  \
# 0         No info   3897           24              3          2019
# 1         No info   7662            5              1          2019
# 2         No info  13882            6              9          2019
#
#    Dep_Time_hour  Dep_Time_minute  Arrival_Time_hour  Arrival_Time_minute
# ...

# %%
cols_to_drop=['Dep_Time','Arrival_Time']
data.drop(cols_to_drop,axis=1,inplace=True)

# %%
data.head(3)
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-01-05   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-09-06     Delhi      Cochin  DEL → LKO → BOM → COK
#
#   Duration Total_Stops Additional_Info  Price  Journey_day  Journey_month  \
# 0   2h 50m    non-stop         No info   3897           24              3
# 1   7h 25m     2 stops         No info   7662            5              1
# 2      19h     2 stops         No info  13882            6              9
#
#    Journey_year  Dep_Time_hour  Dep_Time_minute  Arrival_Time_hour  \
# 0          2019             22               20                  1
# 1          2019              5               50                 13
# 2          2019              9               25                  4
#
#    Arrival_Time_minute
# 0                   10
# 1                   15
# ...

# %%
data.shape
# Out:
# (10682, 16)

# %%
data.head(3)
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-01-05   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-09-06     Delhi      Cochin  DEL → LKO → BOM → COK
#
#   Duration Total_Stops Additional_Info  Price  Journey_day  Journey_month  \
# 0   2h 50m    non-stop         No info   3897           24              3
# 1   7h 25m     2 stops         No info   7662            5              1
# 2      19h     2 stops         No info  13882            6              9
#
#    Journey_year  Dep_Time_hour  Dep_Time_minute  Arrival_Time_hour  \
# 0          2019             22               20                  1
# 1          2019              5               50                 13
# 2          2019              9               25                  4
#
#    Arrival_Time_minute
# 0                   10
# 1                   15
# ...

# %%
def flight_dep_time(x):
    if(x>4) and x<=8:
        return "Early Morning"
    elif(x>8) and x<=12:
        return "Morning"
    elif x>12 and x<=16:
        return "Noon"
    elif x>16 and x<=20:
        return "evening"
    elif x>20 and x<=24:
        return "night"
    else:
        return "late night"

# %%
data['Dep_Time_hour'].apply(flight_dep_time).value_counts().plot(kind='bar',color='g')
# Out:
# <Axes: >

# %%
#!pip install plotly
#!pip install chart_studio

# %%
#!pip install cufflinks

# %%
import plotly
import cufflinks as cf
from cufflinks.offline import go_offline
from plotly.offline import plot,iplot,init_notebook_mode,download_plotlyjs
init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...

# %%
data['Dep_Time_hour'].apply(flight_dep_time).value_counts().iplot(kind='bar')
# Out:
# <div>                            <div id="dd1b9361-5a02-44c8-9ec9-d4256d0539a9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
data['Duration']
# Out:
# 0        2h 50m
# 1        7h 25m
# 2           19h
# 3        5h 25m
# 4        4h 45m
#           ...
# 10678    2h 30m
# 10679    2h 35m
# 10680        3h
# 10681    2h 40m
# 10682    8h 20m
# Name: Duration, Length: 10682, dtype: object

# %%
data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-01-05   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-09-06     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      2019-12-05   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      2019-01-03  Banglore   New Delhi        BLR → NAG → DEL
#
#   Duration Total_Stops Additional_Info  Price  Journey_day  Journey_month  \
# 0   2h 50m    non-stop         No info   3897           24              3
# 1   7h 25m     2 stops         No info   7662            5              1
# 2      19h     2 stops         No info  13882            6              9
# 3   5h 25m      1 stop         No info   6218            5             12
# 4   4h 45m      1 stop         No info  13302            3              1
#
# ...

# %%
splitted=data.Duration.str.split(" ")
splitted
# Out:
# 0        [2h, 50m]
# 1        [7h, 25m]
# 2            [19h]
# 3        [5h, 25m]
# 4        [4h, 45m]
#            ...
# 10678    [2h, 30m]
# 10679    [2h, 35m]
# 10680         [3h]
# 10681    [2h, 40m]
# 10682    [8h, 20m]
# Name: Duration, Length: 10682, dtype: object

# %%
for i in splitted:
    if len(i) < 2:
        if 'm' not in i[0][-1]:
            i.append('0m')
        if 'h' not in i[0][-1]:
            i.insert(0,'0h')
for i in splitted:
    print(i)
# Out:
# ['2h', '50m']
# ['7h', '25m']
# ['19h', '0m']
# ['5h', '25m']
# ['4h', '45m']
# ['2h', '25m']
# ['15h', '30m']
# ['21h', '5m']
# ['25h', '30m']
# ['7h', '50m']
# ['13h', '15m']
# ['2h', '35m']
# ['2h', '15m']
# ['12h', '10m']
# ['2h', '35m']
# ['26h', '35m']
# ['4h', '30m']
# ['22h', '35m']
# ['23h', '0m']
# ['20h', '35m']
# ['5h', '10m']
# ['15h', '20m']
# ['2h', '50m']
# ['2h', '55m']
# ['13h', '20m']
# ['15h', '10m']
# ['5h', '45m']
# ['5h', '55m']
# ['2h', '50m']
# ['2h', '15m']
# ['2h', '15m']
# ['13h', '25m']
# ['2h', '50m']
# ['22h', '0m']
# ['5h', '30m']
# ['10h', '25m']
# ['5h', '15m']
# ['2h', '30m']
# ['6h', '15m']
# ['11h', '55m']
# ['11h', '5m']
# ['8h', '30m']
# ['22h', '5m']
# ['2h', '45m']
# ['12h', '0m']
# ['2h', '50m']
# ['2h', '50m']
# ['2h', '15m']
# ['16h', '5m']
# ['19h', '55m']
# ['3h', '15m']
# ['25h', '20m']
# ['2h', '50m']
# ['3h', '0m']
# ['2h', '50m']
# ['16h', '15m']
# ['15h', '5m']
# ['2h', '15m']
# ['6h', '30m']
# ['25h', '5m']
# ['12h', '25m']
# ...

# %%
hour=[]
minute=[]
for i in splitted:
    hour.append(i[0][:-1])
    minute.append(i[1][:-1])
minute
# Out:
# ['50',
#  '25',
#  '0',
#  '25',
#  '45',
#  '25',
#  '30',
#  '5',
#  '30',
#  '50',
#  '15',
#  '35',
#  '15',
#  '10',
#  '35',
#  '35',
#  '30',
#  '35',
#  '0',
#  '35',
#  '10',
#  '20',
#  '50',
#  '55',
#  '20',
#  '10',
#  '45',
#  '55',
#  '50',
#  '15',
#  '15',
#  '25',
#  '50',
#  '0',
#  '30',
#  '25',
#  '15',
#  '30',
#  '15',
#  '55',
#  '5',
#  '30',
#  '5',
#  '45',
#  '0',
#  '50',
#  '50',
#  '15',
#  '5',
#  '55',
#  '15',
#  '20',
#  '50',
#  '0',
#  '50',
#  '15',
#  '5',
#  '15',
#  '30',
#  '5',
#  '25',
#  '20',
#  '15',
#  '30',
#  '15',
#  '25',
#  '50',
#  '30',
#  '20',
#  '15',
#  '25',
#  '30',
#  '20',
#  '30',
#  '0',
#  '45',
#  '50',
#  '30',
#  '5',
#  '15',
#  '50',
#  '40',
#  '10',
#  '35',
#  '0',
#  '20',
#  '25',
#  '45',
#  '20',
#  '0',
#  '15',
#  '5',
#  '30',
#  '20',
#  '35',
#  '25',
#  '40',
#  '0',
#  '25',
#  '35',
#  '20',
#  '15',
#  '30',
#  '0',
#  '45',
#  '55',
#  '10',
#  '30',
#  '20',
#  '55',
#  '0',
#  '55',
#  '45',
# ...

# %%
data['Duration_hour']=hour
data['Duration_minute']=minute


data['Duration_hour']=data['Duration_hour'].astype(np.int64)
data['Duration_minute']=data['Duration_minute'].astype(np.int64)

# %%
data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-01-05   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-09-06     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      2019-12-05   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      2019-01-03  Banglore   New Delhi        BLR → NAG → DEL
#
#   Duration Total_Stops Additional_Info  Price  Journey_day  Journey_month  \
# 0   2h 50m    non-stop         No info   3897           24              3
# 1   7h 25m     2 stops         No info   7662            5              1
# 2      19h     2 stops         No info  13882            6              9
# 3   5h 25m      1 stop         No info   6218            5             12
# 4   4h 45m      1 stop         No info  13302            3              1
#
# ...

# %%
data.drop('Duration',axis=1,inplace=True)

# %%
data['Additional_Info'].unique()
# Out:
# array(['No info', 'In-flight meal not included',
#        'No check-in baggage included', '1 Short layover', 'No Info',
#        '1 Long layover', 'Change airports', 'Business class',
#        'Red-eye flight', '2 Long layover'], dtype=object)

# %%
(data['Additional_Info'].values == 'No Info')
        
data['Additional_Info'].replace('No Info','No info',inplace=True)

# %%
data['Additional_Info'].unique()
# Out:
# array(['No info', 'In-flight meal not included',
#        'No check-in baggage included', '1 Short layover',
#        '1 Long layover', 'Change airports', 'Business class',
#        'Red-eye flight', '2 Long layover'], dtype=object)

# %%
unique_dict={}
def cols(col):
    for i in col:
        unique_dict[i] = data[i].unique()
cols(data.columns)
unique_dict
# Out:
# {'Airline': array(['IndiGo', 'Air India', 'Jet Airways', 'SpiceJet',
#         'Multiple carriers', 'GoAir', 'Vistara', 'Air Asia',
#         'Vistara Premium economy', 'Jet Airways Business',
#         'Multiple carriers Premium economy', 'Trujet'], dtype=object),
#  'Date_of_Journey': array(['2019-03-24T00:00:00.000000000', '2019-01-05T00:00:00.000000000',
#         '2019-09-06T00:00:00.000000000', '2019-12-05T00:00:00.000000000',
#         '2019-01-03T00:00:00.000000000', '2019-06-24T00:00:00.000000000',
#         '2019-12-03T00:00:00.000000000', '2019-05-27T00:00:00.000000000',
#         '2019-01-06T00:00:00.000000000', '2019-04-18T00:00:00.000000000',
#         '2019-09-05T00:00:00.000000000', '2019-04-24T00:00:00.000000000',
#         '2019-03-03T00:00:00.000000000', '2019-04-15T00:00:00.000000000',
#         '2019-12-06T00:00:00.000000000', '2019-06-03T00:00:00.000000000',
#         '2019-03-21T00:00:00.000000000', '2019-03-04T00:00:00.000000000',
# ...

# %%
data.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Total_Stops', 'Additional_Info', 'Price', 'Journey_day',
#        'Journey_month', 'Journey_year', 'Dep_Time_hour', 'Dep_Time_minute',
#        'Arrival_Time_hour', 'Arrival_Time_minute', 'Duration_hour',
#        'Duration_minute'],
#       dtype='object')

# %%
data[['Duration_hour','Duration_minute']]
# Out:
#        Duration_hour  Duration_minute
# 0                  2               50
# 1                  7               25
# 2                 19                0
# 3                  5               25
# 4                  4               45
# ...              ...              ...
# 10678              2               30
# 10679              2               35
# 10680              3                0
# 10681              2               40
# 10682              8               20
#
# [10682 rows x 2 columns]

# %%
2*60
# Out:
# 120

# %%
data['Duration_Total_Minute']=(data['Duration_hour'] * 60) + data['Duration_minute']
data[['Duration_Total_Minute']].head()
# Out:
#    Duration_Total_Minute
# 0                    170
# 1                    445
# 2                   1140
# 3                    325
# 4                    285

# %%
data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-01-05   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-09-06     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      2019-12-05   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      2019-01-03  Banglore   New Delhi        BLR → NAG → DEL
#
#   Total_Stops Additional_Info  Price  Journey_day  Journey_month  \
# 0    non-stop         No info   3897           24              3
# 1     2 stops         No info   7662            5              1
# 2     2 stops         No info  13882            6              9
# 3      1 stop         No info   6218            5             12
# 4      1 stop         No info  13302            3              1
#
#    Journey_year  Dep_Time_hour  Dep_Time_minute  Arrival_Time_hour  \
# ...

# %%
sns.scatterplot(x=data['Duration_Total_Minute'],y=data.Price,data=data,hue='Total_Stops')
# Out:
# <Axes: xlabel='Duration_Total_Minute', ylabel='Price'>

# %%
data[data.Airline == 'Jet Airways'].groupby('Route').count()
# Out:
#                        Airline  Date_of_Journey  Source  Destination  \
# Route
# BLR → BDQ → DEL              8                8       8            8
# BLR → BOM → DEL            385              385     385          385
# BLR → BOM → JDH → DEL        3                3       3            3
# BLR → DEL                  382              382     382          382
# BLR → MAA → DEL             10               10      10           10
# BOM → BDQ → DEL → HYD        2                2       2            2
# BOM → DED → DEL → HYD        1                1       1            1
# BOM → DEL → HYD              5                5       5            5
# BOM → HYD                  207              207     207          207
# BOM → IDR → DEL → HYD        1                1       1            1
# BOM → JDH → DEL → HYD        1                1       1            1
# BOM → UDR → DEL → HYD        1                1       1            1
# ...

# %%
data[data.Airline == 'Jet Airways'].groupby('Route').size().sort_values()
# Out:
# Route
# DEL → CCU → BOM → COK      1
# BOM → DED → DEL → HYD      1
# BOM → VNS → DEL → HYD      1
# BOM → IDR → DEL → HYD      1
# BOM → JDH → DEL → HYD      1
# BOM → UDR → DEL → HYD      1
# DEL → DED → BOM → COK      2
# BOM → BDQ → DEL → HYD      2
# BLR → BOM → JDH → DEL      3
# CCU → BOM → PNQ → BLR      4
# BOM → DEL → HYD            5
# DEL → UDR → BOM → COK      7
# BLR → BDQ → DEL            8
# BLR → MAA → DEL           10
# DEL → IXC → BOM → COK     13
# DEL → MAA → BOM → COK     16
# CCU → GAU → BLR           22
# DEL → JDH → BOM → COK     23
# DEL → LKO → BOM → COK     25
# DEL → BDQ → BOM → COK     28
# DEL → BHO → BOM → COK     29
# DEL → COK                 34
# DEL → ATQ → BOM → COK     38
# DEL → NAG → BOM → COK     61
# DEL → IDR → BOM → COK     86
# DEL → AMD → BOM → COK    141
# BOM → HYD                207
# DEL → JAI → BOM → COK    207
# CCU → DEL → BLR          300
# BLR → DEL                382
# BLR → BOM → DEL          385
# DEL → BOM → COK          875
# ...

# %%
sns.boxplot(x=data['Airline'],y=data['Price'],data=data.sort_values('Price'))
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.boxplot(x=data['Airline'],y=data['Price'],data=data.sort_values('Price',ascending=False))
plt.xticks(rotation='vertical')
plt.show()

# %%
obj_cols=[]
for i in data.columns:
    if data[i].dtype == object:
        obj_cols.append(i)

# %%
obj_cols
# Out:
# ['Airline', 'Source', 'Destination', 'Route', 'Total_Stops', 'Additional_Info']

# %%
data.dtypes
# Out:
# Airline                          object
# Date_of_Journey          datetime64[ns]
# Source                           object
# Destination                      object
# Route                            object
# Total_Stops                      object
# Additional_Info                  object
# Price                             int64
# Journey_day                       int64
# Journey_month                     int64
# Journey_year                      int64
# Dep_Time_hour                     int64
# Dep_Time_minute                   int64
# Arrival_Time_hour                 int64
# Arrival_Time_minute               int64
# Duration_hour                     int64
# Duration_minute                   int64
# Duration_Total_Minute             int64
# dtype: object

# %% [raw]
# from sklearn.preprocessing import LabelEncoder
# le=LabelEncoder()
# def le_cols(cols):
#     for i in cols:
#         data[i]=le.fit_transform(data[i])
# le_cols(obj_cols)
# data.head()

# %%
unique_obj={}
for i in obj_cols:
    unique_obj[i]=data[i].unique()
unique_obj
# Out:
# {'Airline': array(['IndiGo', 'Air India', 'Jet Airways', 'SpiceJet',
#         'Multiple carriers', 'GoAir', 'Vistara', 'Air Asia',
#         'Vistara Premium economy', 'Jet Airways Business',
#         'Multiple carriers Premium economy', 'Trujet'], dtype=object),
#  'Source': array(['Banglore', 'Kolkata', 'Delhi', 'Chennai', 'Mumbai'], dtype=object),
#  'Destination': array(['New Delhi', 'Banglore', 'Cochin', 'Kolkata', 'Delhi', 'Hyderabad'],
#        dtype=object),
#  'Route': array(['BLR → DEL', 'CCU → IXR → BBI → BLR', 'DEL → LKO → BOM → COK',
#         'CCU → NAG → BLR', 'BLR → NAG → DEL', 'CCU → BLR',
#         'BLR → BOM → DEL', 'DEL → BOM → COK', 'DEL → BLR → COK',
#         'MAA → CCU', 'CCU → BOM → BLR', 'DEL → AMD → BOM → COK',
#         'DEL → PNQ → COK', 'DEL → CCU → BOM → COK', 'BLR → COK → DEL',
#         'DEL → IDR → BOM → COK', 'DEL → LKO → COK',
#         'CCU → GAU → DEL → BLR', 'DEL → NAG → BOM → COK',
# ...

# %% [markdown]
# ## One Hot encoding without using sklearn

# %%
source_uni=data['Source'].unique()
source_uni
# Out:
# array(['Banglore', 'Kolkata', 'Delhi', 'Chennai', 'Mumbai'], dtype=object)

# %%
data['Source'].apply(lambda x:1 if x=='Banglore' else 0)
# Out:
# 0        1
# 1        0
# 2        0
# 3        0
# 4        1
#         ..
# 10678    0
# 10679    0
# 10680    1
# 10681    1
# 10682    0
# Name: Source, Length: 10682, dtype: int64

# %%
for i in source_uni:
    data['Source_'+i]=data['Source'].apply(lambda x:1 if x==i else 0)

# %% [raw]
# for i in source_uni:
#     data.drop(['Source_'+i],axis=1,inplace=True)

# %%
data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-01-05   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-09-06     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      2019-12-05   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      2019-01-03  Banglore   New Delhi        BLR → NAG → DEL
#
#   Total_Stops Additional_Info  Price  Journey_day  Journey_month  ...  \
# 0    non-stop         No info   3897           24              3  ...
# 1     2 stops         No info   7662            5              1  ...
# 2     2 stops         No info  13882            6              9  ...
# 3      1 stop         No info   6218            5             12  ...
# 4      1 stop         No info  13302            3              1  ...
#
#    Arrival_Time_hour  Arrival_Time_minute  Duration_hour  Duration_minute  \
# ...

# %% [markdown]
# ## Target Encoding

# %%
data['Airline'].nunique()
# Out:
# 12

# %%
data.groupby(['Airline'])['Price'].mean().sort_values()
# Out:
# Airline
# Trujet                                4140.000000
# SpiceJet                              4338.284841
# Air Asia                              5590.260188
# IndiGo                                5673.682903
# GoAir                                 5861.056701
# Vistara                               7796.348643
# Vistara Premium economy               8962.333333
# Air India                             9612.427756
# Multiple carriers                    10902.678094
# Multiple carriers Premium economy    11418.846154
# Jet Airways                          11643.923357
# Jet Airways Business                 58358.666667
# Name: Price, dtype: float64

# %%
airlines=data.groupby(['Airline'])['Price'].mean().sort_values().index
airlines
# Out:
# Index(['Trujet', 'SpiceJet', 'Air Asia', 'IndiGo', 'GoAir', 'Vistara',
#        'Vistara Premium economy', 'Air India', 'Multiple carriers',
#        'Multiple carriers Premium economy', 'Jet Airways',
#        'Jet Airways Business'],
#       dtype='object', name='Airline')

# %%
airlines_dict={}
for i,k in enumerate(airlines,0):
    airlines_dict[k]=i
airlines_dict
# Out:
# {'Trujet': 0,
#  'SpiceJet': 1,
#  'Air Asia': 2,
#  'IndiGo': 3,
#  'GoAir': 4,
#  'Vistara': 5,
#  'Vistara Premium economy': 6,
#  'Air India': 7,
#  'Multiple carriers': 8,
#  'Multiple carriers Premium economy': 9,
#  'Jet Airways': 10,
#  'Jet Airways Business': 11}

# %%
data['Airline']=data['Airline'].map(airlines_dict)

# %%
data.head()
# Out:
#    Airline Date_of_Journey    Source Destination                  Route  \
# 0        3      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1        7      2019-01-05   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2       10      2019-09-06     Delhi      Cochin  DEL → LKO → BOM → COK
# 3        3      2019-12-05   Kolkata    Banglore        CCU → NAG → BLR
# 4        3      2019-01-03  Banglore   New Delhi        BLR → NAG → DEL
#
#   Total_Stops Additional_Info  Price  Journey_day  Journey_month  ...  \
# 0    non-stop         No info   3897           24              3  ...
# 1     2 stops         No info   7662            5              1  ...
# 2     2 stops         No info  13882            6              9  ...
# 3      1 stop         No info   6218            5             12  ...
# 4      1 stop         No info  13302            3              1  ...
#
#    Arrival_Time_hour  Arrival_Time_minute  Duration_hour  Duration_minute  \
# ...

# %%
data.Destination.unique()
# Out:
# array(['New Delhi', 'Banglore', 'Cochin', 'Kolkata', 'Delhi', 'Hyderabad'],
#       dtype=object)

# %%
dest=data.groupby(['Destination'])['Price'].mean().sort_values().index
dest
# Out:
# Index(['Kolkata', 'Hyderabad', 'Delhi', 'Banglore', 'Cochin', 'New Delhi'], dtype='object', name='Destination')

# %%
dest_dict={k:i for i,k in enumerate(dest,0)}
dest_dict
# Out:
# {'Kolkata': 0,
#  'Hyderabad': 1,
#  'Delhi': 2,
#  'Banglore': 3,
#  'Cochin': 4,
#  'New Delhi': 5}

# %%
data.Destination=data.Destination.map(dest_dict)
data.head()
# Out:
#    Airline Date_of_Journey    Source  Destination                  Route  \
# 0        3      2019-03-24  Banglore            5              BLR → DEL
# 1        7      2019-01-05   Kolkata            3  CCU → IXR → BBI → BLR
# 2       10      2019-09-06     Delhi            4  DEL → LKO → BOM → COK
# 3        3      2019-12-05   Kolkata            3        CCU → NAG → BLR
# 4        3      2019-01-03  Banglore            5        BLR → NAG → DEL
#
#   Total_Stops Additional_Info  Price  Journey_day  Journey_month  ...  \
# 0    non-stop         No info   3897           24              3  ...
# 1     2 stops         No info   7662            5              1  ...
# 2     2 stops         No info  13882            6              9  ...
# 3      1 stop         No info   6218            5             12  ...
# 4      1 stop         No info  13302            3              1  ...
#
#    Arrival_Time_hour  Arrival_Time_minute  Duration_hour  Duration_minute  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data['Additional_Info']=le.fit_transform(data['Additional_Info'])
data.head(3)
# Out:
#    Airline Date_of_Journey    Source  Destination                  Route  \
# 0        3      2019-03-24  Banglore            5              BLR → DEL
# 1        7      2019-01-05   Kolkata            3  CCU → IXR → BBI → BLR
# 2       10      2019-09-06     Delhi            4  DEL → LKO → BOM → COK
#
#   Total_Stops  Additional_Info  Price  Journey_day  Journey_month  ...  \
# 0    non-stop                7   3897           24              3  ...
# 1     2 stops                7   7662            5              1  ...
# 2     2 stops                7  13882            6              9  ...
#
#    Arrival_Time_hour  Arrival_Time_minute  Duration_hour  Duration_minute  \
# 0                  1                   10              2               50
# 1                 13                   15              7               25
# 2                  4                   25             19                0
#
#    Duration_Total_Minute  Source_Banglore  Source_Kolkata  Source_Delhi  \
# ...

# %%
data['Additional_Info'].unique()
# Out:
# array([7, 5, 6, 1, 0, 4, 3, 8, 2])

# %%
total_uni=data['Total_Stops'].unique()

# %%
total_dict={k:i for i,k in enumerate(total_uni)}
total_dict
# Out:
# {'non-stop': 0, '2 stops': 1, '1 stop': 2, '3 stops': 3, '4 stops': 4}

# %%
data['Total_Stops']=data['Total_Stops'].map(total_dict)

# %%
data['Total_Stops'].head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    2
# 4    2
# Name: Total_Stops, dtype: int64

# %%
data.head(1)
# Out:
#    Airline Date_of_Journey    Source  Destination      Route  Total_Stops  \
# 0        3      2019-03-24  Banglore            5  BLR → DEL            0
#
#    Additional_Info  Price  Journey_day  Journey_month  ...  Arrival_Time_hour  \
# 0                7   3897           24              3  ...                  1
#
#    Arrival_Time_minute  Duration_hour  Duration_minute  Duration_Total_Minute  \
# 0                   10              2               50                    170
#
#    Source_Banglore  Source_Kolkata  Source_Delhi  Source_Chennai  \
# 0                1               0             0               0
#
#    Source_Mumbai
# 0              0
#
# [1 rows x 23 columns]

# %%
data.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Total_Stops', 'Additional_Info', 'Price', 'Journey_day',
#        'Journey_month', 'Journey_year', 'Dep_Time_hour', 'Dep_Time_minute',
#        'Arrival_Time_hour', 'Arrival_Time_minute', 'Duration_hour',
#        'Duration_minute', 'Duration_Total_Minute', 'Source_Banglore',
#        'Source_Kolkata', 'Source_Delhi', 'Source_Chennai', 'Source_Mumbai'],
#       dtype='object')

# %% [markdown]
# ## Remove uneccessary features

# %%
#data.Journey_year.unique()

# %%
data.drop(['Route','Additional_Info','Source','Date_of_Journey','Duration_Total_Minute','Journey_year'],axis=1,inplace=True)

# %%
data.head()
# Out:
#    Airline  Destination  Total_Stops    Price  Journey_day  Journey_month  \
# 0        3            5            0   3897.0           24              3
# 1        7            3            1   7662.0            5              1
# 2       10            4            1  13882.0            6              9
# 3        3            3            2   6218.0            5             12
# 4        3            5            2  13302.0            3              1
#
#    Dep_Time_hour  Dep_Time_minute  Arrival_Time_hour  Arrival_Time_minute  \
# 0             22               20                  1                   10
# 1              5               50                 13                   15
# 2              9               25                  4                   25
# 3             18                5                 23                   30
# 4             16               50                 21                   35
#
#    Duration_hour  Duration_minute  Source_Banglore  Source_Kolkata  \
# ...

# %% [markdown]
# ## Handle outliers

# %%
def plot(df,col):
    fig,(ax1,ax2,ax3)=plt.subplots(3,1)
    sns.histplot(df[col],ax=ax1)
    sns.boxplot(df[col],ax=ax2)
    sns.distplot(df[col],ax=ax3,kde=False)
plot(data,'Price')

# %%
q1=data['Price'].quantile(0.25)
q3=data['Price'].quantile(0.75)
iqr=q3-q1

maximum=q3+1.5*iqr
minimum=q1-1.5*iqr
print(maximum)
print(minimum)
# Out:
# 23017.0
# -5367.0

# %%
data['Price']=np.where(data['Price']>=35000,data['Price'].median(),data['Price'])

# %%
plot(data,'Price')

# %% [markdown]
# ## Feature Selection

# %%
y=data.Price
y
# Out:
# 0         3897.0
# 1         7662.0
# 2        13882.0
# 3         6218.0
# 4        13302.0
#           ...
# 10678     4107.0
# 10679     4145.0
# 10680     7229.0
# 10681    12648.0
# 10682    11753.0
# Name: Price, Length: 10682, dtype: float64

# %%
x=data.drop(['Price'],axis=1)
x
# Out:
#        Airline  Destination  Total_Stops  Journey_day  Journey_month  \
# 0            3            5            0           24              3
# 1            7            3            1            5              1
# 2           10            4            1            6              9
# 3            3            3            2            5             12
# 4            3            5            2            3              1
# ...        ...          ...          ...          ...            ...
# 10678        2            3            0            4              9
# 10679        7            3            0           27              4
# 10680       10            2            0           27              4
# 10681        5            5            0            3              1
# 10682        7            4            1            5              9
#
#        Dep_Time_hour  Dep_Time_minute  Arrival_Time_hour  Arrival_Time_minute  \
# ...

# %%
from sklearn.feature_selection import mutual_info_regression
imp=mutual_info_regression(x,y)
imp
# Out:
# array([0.98062441, 1.11818171, 0.78931297, 0.19025496, 0.24192714,
#        0.33592877, 0.25470299, 0.3969361 , 0.34514199, 0.46771937,
#        0.34779336, 0.39353706, 0.4560266 , 0.52190869, 0.13652769,
#        0.19180527])

# %%
imp_df=pd.DataFrame(imp,index=x.columns)
imp_df.columns=['Important']
imp_df
# Out:
#                      Important
# Airline               0.980624
# Destination           1.118182
# Total_Stops           0.789313
# Journey_day           0.190255
# Journey_month         0.241927
# Dep_Time_hour         0.335929
# Dep_Time_minute       0.254703
# Arrival_Time_hour     0.396936
# Arrival_Time_minute   0.345142
# Duration_hour         0.467719
# Duration_minute       0.347793
# Source_Banglore       0.393537
# Source_Kolkata        0.456027
# Source_Delhi          0.521909
# Source_Chennai        0.136528
# Source_Mumbai         0.191805

# %%
imp_df.sort_values(by='Important',ascending=False)
# Out:
#                      Important
# Destination           1.118182
# Airline               0.980624
# Total_Stops           0.789313
# Source_Delhi          0.521909
# Duration_hour         0.467719
# Source_Kolkata        0.456027
# Arrival_Time_hour     0.396936
# Source_Banglore       0.393537
# Duration_minute       0.347793
# Arrival_Time_minute   0.345142
# Dep_Time_hour         0.335929
# Dep_Time_minute       0.254703
# Journey_month         0.241927
# Source_Mumbai         0.191805
# Journey_day           0.190255
# Source_Chennai        0.136528

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
ml_model=RandomForestRegressor()
ml_model.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred=ml_model.predict(x_test)

# %%
y_pred
# Out:
# array([16696.01,  6300.13,  8882.05, ...,  3474.4 ,  6294.14,  7296.98])

# %%
from sklearn import metrics
metrics.r2_score(y_test,y_pred)
# Out:
# 0.8028482635502565

# %%
import pickle
file=open('RandomForestModel/rf_random_file','wb')
pickle.dump(ml_model,file)
model=open(r'RandomForestModel/rf_random_file','rb')
forest=pickle.load(model)
y_pred2=forest.predict(x_test)
metrics.r2_score(y_test,y_pred)
# Out:
# 0.8028482635502565

# %%
def mape(y_true,y_pred):
    y_true,y_pred=np.array(y_true),np.array(y_pred)
    return np.mean(np.abs((y_true-y_pred)/y_true)) *100

# %%
mape(y_test,y_pred)
# Out:
# 13.26840777554985

# %% [markdown]
# ## Pipeline

# %%
def predict(ml_model):
    model=ml_model.fit(x_train,y_train)
    print('Training score {}'.format(model.score(x_train,y_train)))
    y_predict=model.predict(x_test)
    print("Predictions are: ",y_predict)
    print('\n')
    r2_score=metrics.r2_score(y_test,y_predict)
    print('R2 Score: ',r2_score)
    print("MAE: ",metrics.mean_absolute_error(y_test,y_predict))
    print('MSE: ',metrics.mean_squared_error(y_test,y_predict))
    print('RMSE: ',np.sqrt(metrics.mean_squared_error(y_test,y_predict)))
    print('MAPE: ',mape(y_test,y_predict))
    sns.distplot(y_test-y_predict)

# %%
predict(RandomForestRegressor())
# Out:
# Training score 0.9513811257922152
# Predictions are:  [16785.4   6166.19  8860.89 ...  3525.95  6272.11  7171.61]
#
#
# R2 Score:  0.8045327149354511
# MAE:  1189.8275289540838
# MSE:  3805278.8533251514
# RMSE:  1950.712396363224
# MAPE:  13.306595116148204

# %%
from sklearn.tree import DecisionTreeRegressor
predict(DecisionTreeRegressor())
# Out:
# Training score 0.966591628243878
# Predictions are:  [16840.  6976.  8610. ...  3419.  5797.  6818.]
#
#
# R2 Score:  0.6872877849985797
# MAE:  1389.9551728441284
# MSE:  6087756.212137568
# RMSE:  2467.337879605784
# MAPE:  15.454198448094104
